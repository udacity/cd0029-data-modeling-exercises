# %% [markdown]
# # Exercise 1: Identifying Data, Information, and Knowledge - Solutions

# %%
# %%capture
# %config SqlMagic.autopandas = True;
# %config SqlMagic.feedback = False;
# %config SqlMagic.displaycon = False;
import duckdb;
import os;
# %load_ext sql
conn = duckdb.connect();
# %sql conn --alias duckdb
# %sql duckdb:///:memory:
# %sql CREATE TABLE raw_survey AS SELECT * FROM '../data/survey_results_public.parquet';

# %% [markdown]
# #### Task 1: Fill in the blank after GROUP BY below to start. Note, in DuckDB SQL, you can GROUP BY aliases.

# %%
# %%sql
# SELECT
#     STRING_SPLIT(LanguageHaveWorkedWith, ';') AS Language,
#     MEDIAN(CAST(ConvertedCompYearly AS INT)) AS MedSalary
# FROM
#     raw_survey
# WHERE
#     LanguageHaveWorkedWith IS NOT NULL
#     AND ConvertedCompYearly IS NOT NULL
#     AND ConvertedCompYearly != 'NA'
#     --Language is the solution
#     GROUP BY Language
# LIMIT 20;
# Out:
#                                              Language  MedSalary
# 0   [C#, C++, JavaScript, Python, Visual Basic (.N...    87500.0
# 1   [HTML/CSS, Java, JavaScript, PHP, PowerShell, ...    50052.0
# 2   [Assembly, Bash/Shell (all shells), C, C++, Go...    62767.0
# 3   [C#, HTML/CSS, JavaScript, PowerShell, Python,...   119254.5
# 4   [Go, HTML/CSS, JavaScript, PHP, PowerShell, Py...   145018.0
# 5   [Bash/Shell (all shells), C#, C++, F#, Go, HTM...   131000.0
# 6                       [Dart, Java, JavaScript, SQL]    31346.5
# 7                               [HTML/CSS, Java, SQL]    34804.5
# 8             [HTML/CSS, JavaScript, SQL, TypeScript]    51000.0
# 9   [Bash/Shell (all shells), Groovy, HTML/CSS, Ja...    77730.0
# 10  [C, Go, HTML/CSS, Java, JavaScript, Python, SQ...    60518.0
# 11  [Bash/Shell (all shells), HTML/CSS, Java, Java...    60907.5
# 12  [Bash/Shell (all shells), C#, HTML/CSS, PowerS...   200000.0
# 13  [Bash/Shell (all shells), C#, HTML/CSS, JavaSc...    63226.0
# 14  [Bash/Shell (all shells), C#, Elixir, Go, HTML...   135000.0
# 15  [Assembly, Bash/Shell (all shells), C, HTML/CS...    79245.0
# 16  [Bash/Shell (all shells), HTML/CSS, JavaScript...   121815.5
# 17  [Bash/Shell (all shells), C#, Go, HTML/CSS, Ja...    80822.5
# 18  [C, C#, Go, HTML/CSS, JavaScript, Python, R, R...    37554.0
# 19  [Bash/Shell (all shells), C, C++, HTML/CSS, Ja...   112098.5

# %% [markdown]
# #### Task 2: Modify the query from Part B to filter for results where Country is 'United States of America' and YearsCodingExp is between 5 and 10 years.

# %%
# %%sql
# SELECT
#     STRING_SPLIT(LanguageHaveWorkedWith, ';') AS Language,
#     MEDIAN(CAST(ConvertedCompYearly AS INT)) AS MedSalary,
#     CAST(YearsCode AS INT) AS YearsCodingExp
# FROM
#     raw_survey
# WHERE
#     LanguageHaveWorkedWith IS NOT NULL
#     AND ConvertedCompYearly IS NOT NULL
#     AND ConvertedCompYearly != 'NA'
#     AND YearsCode != 'NA'
#     -- BETWEEN 5 AND 10 is the solution
#     -- Country = 'United States of America' is the solution
#     AND YearsCodingExp BETWEEN 5 AND 10
#     AND Country = 'United States of America'
# GROUP BY
#     Language,
#     YearsCodingExp
# ORDER BY
#     YearsCodingExp DESC
# LIMIT 100;
# Out:
#                                              Language  MedSalary  \
# 0                             [Go, Python, Ruby, SQL]   185000.0
# 1   [Bash/Shell (all shells), PowerShell, Python, ...   100000.0
# 2   [Bash/Shell (all shells), C#, Erlang, Go, HTML...    90000.0
# 3               [C#, Dart, HTML/CSS, SQL, TypeScript]   136000.0
# 4   [C#, HTML/CSS, Java, JavaScript, Python, SQL, ...   130000.0
# ..                                                ...        ...
# 95  [Bash/Shell (all shells), Go, HTML/CSS, JavaSc...      190.0
# 96  [Bash/Shell (all shells), HTML/CSS, JavaScript...   150000.0
# 97  [Bash/Shell (all shells), C#, Groovy, PowerShe...   127000.0
# 98                            [Lua, Python, SQL, VBA]   878500.0
# 99  [Bash/Shell (all shells), C#, F#, HTML/CSS, Ja...   134000.0
#
#     YearsCodingExp
# 0               10
# 1               10
# 2               10
# 3               10
# 4               10
# ..             ...
# 95              10
# 96              10
# 97              10
# 98              10
# 99              10
#
# [100 rows x 3 columns]

# %% [markdown]
# #### Task 3: Replace blanks with the correct conditional statements for the CASE expression, and the WHERE clause.

# %%
# %%sql
# SELECT
#     STRING_SPLIT(LanguageHaveWorkedWith, ';') AS Language,
#     MEDIAN(CAST(ConvertedCompYearly AS INT)) AS MedSalary,
#     CAST(YearsCode AS INT) AS YearsCodingExp,
#     CASE WHEN YearsCodingExp >= 0 AND YearsCodingExp <= 10 THEN ' 0 - 10'
#         WHEN YearsCodingExp > 10 AND YearsCodingExp <= 25 THEN '10+ - 25'
#         -- YearsCodingExp > 25 AND YearsCodingExp <= 50 THEN '50+ - 100' is the solution
#         WHEN YearsCodingExp > 25 AND YearsCodingExp <= 50 THEN '50+ - 100'
#     END AS YearsCodingExpBucket
# FROM
#     raw_survey
# WHERE
#     LanguageHaveWorkedWith IS NOT NULL
#     AND ConvertedCompYearly IS NOT NULL
#     AND ConvertedCompYearly != 'NA'
#     AND YearsCode != 'NA'
#     -- BETWEEN 5 AND 10 is the solution
#     -- Country = 'United States of America' is the solution
#     AND YearsCodingExp BETWEEN 5 AND 10
#     AND Country = 'United States of America'
# GROUP BY
#     Language,
#     YearsCodingExp
# ORDER BY
#     YearsCodingExp DESC
# LIMIT 100;
# Out:
#                                              Language  MedSalary  \
# 0   [C#, HTML/CSS, JavaScript, Python, Rust, SQL, ...   160000.0
# 1   [C#, HTML/CSS, JavaScript, PowerShell, SQL, Ty...    88500.0
# 2   [Bash/Shell (all shells), C#, JavaScript, Powe...   150000.0
# 3   [Bash/Shell (all shells), Elixir, HTML/CSS, Ja...   155000.0
# 4   [Bash/Shell (all shells), Go, HTML/CSS, Java, ...   350000.0
# ..                                                ...        ...
# 95         [Bash/Shell (all shells), C++, Go, Python]   150000.0
# 96  [Bash/Shell (all shells), C#, HTML/CSS, JavaSc...   100000.0
# 97  [Bash/Shell (all shells), C, C#, Go, HTML/CSS,...     8000.0
# 98  [Bash/Shell (all shells), HTML/CSS, JavaScript...   190000.0
# 99  [COBOL, Groovy, HTML/CSS, Java, JavaScript, Ko...   148000.0
#
#     YearsCodingExp YearsCodingExpBucket
# 0               10               0 - 10
# 1               10               0 - 10
# 2               10               0 - 10
# 3               10               0 - 10
# 4               10               0 - 10
# ..             ...                  ...
# 95              10               0 - 10
# 96              10               0 - 10
# 97              10               0 - 10
# 98              10               0 - 10
# 99              10               0 - 10
#
# [100 rows x 4 columns]

# %% [markdown]
# #### Task 4: Fill in the blanks as part of the last piece of the WHERE clause to have only Rust users appear in the filter. Do the same afterwards, but for C++ users.

# %%
# %%sql
# SELECT
#     'Rust' AS Language,
#     MEDIAN(CAST(ConvertedCompYearly AS INT)) AS MedSalary,
#     CASE WHEN CAST(YearsCode AS INT)  >= 0 AND CAST(YearsCode AS INT)  <= 10 THEN ' 0 - 10'
#         WHEN CAST(YearsCode AS INT)  > 10 AND CAST(YearsCode AS INT)  <= 25 THEN '10+ - 25'
#         WHEN CAST(YearsCode AS INT)  > 25 AND CAST(YearsCode AS INT)  <= 50 THEN '50+ - 100'
#     END AS YearsCodingExpBucket
# FROM
#     raw_survey
# WHERE
#     LanguageHaveWorkedWith IS NOT NULL
#     AND ConvertedCompYearly IS NOT NULL
#     AND ConvertedCompYearly != 'NA'
#     AND YearsCode != 'NA'
#     AND YearsCodingExpBucket != 'None'
#     AND Country = 'United States of America'
#     -- 'Rust' IN STRING_SPLIT(LanguageHaveWorkedWith, ';') is the solution
#     AND 'Rust' IN STRING_SPLIT(LanguageHaveWorkedWith, ';')
# GROUP BY
#     Language,
#     YearsCodingExpBucket
# ORDER BY
#     YearsCodingExpBucket DESC
# LIMIT 100;
# Out:
#   Language  MedSalary YearsCodingExpBucket
# 0     Rust   200000.0            50+ - 100
# 1     Rust   170000.0             10+ - 25
# 2     Rust    91000.0               0 - 10

# %%
# %%sql
# SELECT
#     'C++' AS Language,
#     MEDIAN(CAST(ConvertedCompYearly AS INT)) AS MedSalary,
#     CASE WHEN CAST(YearsCode AS INT)  >= 0 AND CAST(YearsCode AS INT)  <= 10 THEN ' 0 - 10'
#         WHEN CAST(YearsCode AS INT)  > 10 AND CAST(YearsCode AS INT)  <= 25 THEN '10+ - 25'
#         WHEN CAST(YearsCode AS INT)  > 25 AND CAST(YearsCode AS INT)  <= 50 THEN '50+ - 100'
#     END AS YearsCodingExpBucket
# FROM
#     raw_survey
# WHERE
#     LanguageHaveWorkedWith IS NOT NULL
#     AND ConvertedCompYearly IS NOT NULL
#     AND ConvertedCompYearly != 'NA'
#     AND YearsCode != 'NA'
#     AND YearsCodingExpBucket != 'None'
#     AND Country = 'United States of America'
#     --'C++' IN STRING_SPLIT(LanguageHaveWorkedWith, ';') is the solution
#     --AND 'C++' IN STRING_SPLIT(LanguageHaveWorkedWith, ';')
# GROUP BY
#     Language,
#     YearsCodingExpBucket
# ORDER BY
#     YearsCodingExpBucket DESC
# LIMIT 100;
# Out:
#   Language  MedSalary YearsCodingExpBucket
# 0      C++   174000.0            50+ - 100
# 1      C++   154000.0             10+ - 25
# 2      C++   100000.0               0 - 10

# %% [markdown]
# #### Task 5: Fill in the blanks as part of the last piece of the WHERE clause to have only Rust users AND C++ users appear in the filter.

# %%
# %%sql
# SELECT
#     'C++ and Rust' AS Language,
#     MEDIAN(CAST(ConvertedCompYearly AS INT)) AS MedSalary,
#     CASE WHEN CAST(YearsCode AS INT)  >= 0 AND CAST(YearsCode AS INT)  <= 10 THEN ' 0 - 10'
#         WHEN CAST(YearsCode AS INT)  > 10 AND CAST(YearsCode AS INT)  <= 25 THEN '10+ - 25'
#         WHEN CAST(YearsCode AS INT)  > 25 AND CAST(YearsCode AS INT)  <= 50 THEN '50+ - 100'
#     END AS YearsCodingExpBucket
# FROM
#     raw_survey
# WHERE
#     LanguageHaveWorkedWith IS NOT NULL
#     AND ConvertedCompYearly IS NOT NULL
#     AND ConvertedCompYearly != 'NA'
#     AND YearsCode != 'NA'
#     AND YearsCodingExpBucket != 'None'
#     AND Country = 'United States of America'
#     --'C++' IN STRING_SPLIT(LanguageHaveWorkedWith, ';') is the solution
#     AND 'C++' IN STRING_SPLIT(LanguageHaveWorkedWith, ';')
#     -- 'Rust' IN STRING_SPLIT(LanguageHaveWorkedWith, ';') is the solution
#     AND 'Rust' IN STRING_SPLIT(LanguageHaveWorkedWith, ';')
# GROUP BY
#     Language,
#     YearsCodingExpBucket
# ORDER BY
#     YearsCodingExpBucket DESC
# LIMIT 100;
# Out:
#        Language  MedSalary YearsCodingExpBucket
# 0  C++ and Rust   206000.0            50+ - 100
# 1  C++ and Rust   150000.0             10+ - 25
# 2  C++ and Rust    80000.0               0 - 10

# %% [markdown]
# #### Task 6: Fill in the blanks as part of the last piece of the WHERE clause to have both PostgreSQL users OR MongoDB users appear in the filter.

# %%
# %%sql
# SELECT
#     CASE WHEN 'MongoDB' IN STRING_SPLIT(DatabaseHaveWorkedWith, ';') AND 'PostgreSQL' IN STRING_SPLIT(DatabaseHaveWorkedWith, ';') THEN 'MongoDB & PostgreSQL'
#          WHEN 'MongoDB' IN STRING_SPLIT(DatabaseHaveWorkedWith, ';') THEN 'MongoDB'
#          WHEN 'PostgreSQL' IN STRING_SPLIT(DatabaseHaveWorkedWith, ';') THEN 'PostgreSQL' END AS DatabaseExp,
#     MEDIAN(CAST(ConvertedCompYearly AS INT)) AS MedSalary,
#     CASE WHEN CAST(YearsCode AS INT)  >= 0 AND CAST(YearsCode AS INT)  <= 10 THEN ' 0 - 10'
#         WHEN CAST(YearsCode AS INT)  > 10 AND CAST(YearsCode AS INT)  <= 25 THEN '10+ - 25'
#         WHEN CAST(YearsCode AS INT)  > 25 AND CAST(YearsCode AS INT)  <= 50 THEN '50+ - 100'
#     END AS YearsCodingExpBucket
# FROM
#     raw_survey
# WHERE
#     DatabaseExp IS NOT NULL
#     AND ConvertedCompYearly IS NOT NULL
#     AND ConvertedCompYearly != 'NA'
#     AND YearsCode != 'NA'
#     AND YearsCodingExpBucket != 'None'
#     AND Country = 'United States of America'
#     -- ('MongoDB' IN DatabaseExp OR 'PostgreSQL' IN DatabaseExp) is the solution
#     AND ('MongoDB' IN DatabaseExp OR 'PostgreSQL' IN DatabaseExp)
# GROUP BY
#     DatabaseExp,
#     YearsCodingExpBucket
# ORDER BY
#     DatabaseExp, YearsCodingExpBucket DESC
# LIMIT 100;
# Out:
#             DatabaseExp  MedSalary YearsCodingExpBucket
# 0               MongoDB   165000.0            50+ - 100
# 1               MongoDB   150000.0             10+ - 25
# 2               MongoDB    95750.0               0 - 10
# 3  MongoDB & PostgreSQL   185000.0            50+ - 100
# 4  MongoDB & PostgreSQL   170000.0             10+ - 25
# 5  MongoDB & PostgreSQL   122000.0               0 - 10
# 6            PostgreSQL   184500.0            50+ - 100
# 7            PostgreSQL   168000.0             10+ - 25
# 8            PostgreSQL   112000.0               0 - 10

# %% [markdown]
# ## Standout:
# What are some potential pitfalls of this type of analysis? We believe we have found some patterns we know to be true, but how could we have erred in coming to these conclusions?

# %% [markdown]
# #### This is freeform answer.
